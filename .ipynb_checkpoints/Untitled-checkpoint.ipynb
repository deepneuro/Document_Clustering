# %%
import pather
import time
import importlib
import pdfparser

# %%
time1 = time.time()
paths = pather.find_pdf_paths(r'C:\Users\sergiojesus\Desktop\Coisas da Alvita\CV', 'pdf')
print(time.time()-time1)
# Out:
# 0.12266874313354492

# %%
time1 = time.time()
files = pather.return_last_element(paths)
print(time.time()-time1)
# Out:
# 0.006980419158935547

# %%
time1 = time.time()
pathways = pather.return_first_elements(paths)
print(time.time()-time1)
# Out:
# 0.0099945068359375

# %%
files
# Out:
# ['Abel Cláudio Fernandes Ribeiro.pdf',
#  'Abilio António Silva Martins.pdf',
#  'Ademar Marcos.pdf',
#  'Aderito Oscar Gonçalves Chimuangueno.pdf',
#  'Adilson Cleiton da Silva.pdf',
#  'Afonso Alberto Paciencia.pdf',
#  'Alexandra Alice Herbert Lopes Almeida.pdf',
#  'Amilton Bumba Mascote.pdf',
#  'Ana Christina Tavares.pdf',
#  'Ana Cláudia O. R. Lacerda Ferreira.pdf',
#  'Ana Filipa Pereira Afonso.pdf',
#  'Ana Luísa de Andrade Tomás Saraiva.pdf',
#  'Ana Maria Carita Félix Neves.pdf',
#  'Ana Patrícia de Sousa Araújo.pdf',
#  'Ana Rita Lopes Ferreira.pdf',
#  'Ana Rita Pereira Araújo.pdf',
#  'Ana Tatiana Mimoso Boneco.pdf',
#  'Anabela Fernandes de Oliveira.pdf',
#  'Anabela Susana Leite Barroso.pdf',
#  'Andreia da Conceição Pacheco de Oliveira.pdf',
#  'Andreia Duarte Vieira.pdf',
#  'Andreia Filipa Teixeira Claro.pdf',
#  'Andreia Sofia Revez Martins.pdf',
#  'André Afonso.pdf',
#  'André António Corticeiro Santos.pdf',
#  'André Filipe Oliveira Câmara.pdf',
# ...

# %%
pathways
# Out:
# ['C:\\Users\\sergiojesus\\Desktop\\Coisas da Alvita\\CV\\05-Maio 2016\\',
#  'C:\\Users\\sergiojesus\\Desktop\\Coisas da Alvita\\CV\\05-Maio 2016\\',
#  'C:\\Users\\sergiojesus\\Desktop\\Coisas da Alvita\\CV\\05-Maio 2016\\',
#  'C:\\Users\\sergiojesus\\Desktop\\Coisas da Alvita\\CV\\05-Maio 2016\\',
#  'C:\\Users\\sergiojesus\\Desktop\\Coisas da Alvita\\CV\\05-Maio 2016\\',
#  'C:\\Users\\sergiojesus\\Desktop\\Coisas da Alvita\\CV\\05-Maio 2016\\',
#  'C:\\Users\\sergiojesus\\Desktop\\Coisas da Alvita\\CV\\05-Maio 2016\\',
#  'C:\\Users\\sergiojesus\\Desktop\\Coisas da Alvita\\CV\\05-Maio 2016\\',
#  'C:\\Users\\sergiojesus\\Desktop\\Coisas da Alvita\\CV\\05-Maio 2016\\',
#  'C:\\Users\\sergiojesus\\Desktop\\Coisas da Alvita\\CV\\05-Maio 2016\\',
#  'C:\\Users\\sergiojesus\\Desktop\\Coisas da Alvita\\CV\\05-Maio 2016\\',
#  'C:\\Users\\sergiojesus\\Desktop\\Coisas da Alvita\\CV\\05-Maio 2016\\',
#  'C:\\Users\\sergiojesus\\Desktop\\Coisas da Alvita\\CV\\05-Maio 2016\\',
# ...

# %%
import pdf2txt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-60-7710bedb5dd0> in <module>()
# ----> 1 import pdf2txt
#
# ModuleNotFoundError: No module named 'pdf2txt'

# %%
path = C:\Users\sergiojesus\Desktop\Document_Clustering\CV_EmanuelOliveira_pt.pdf
# Out:
#   File "<ipython-input-68-e16eb3a4a4de>", line 1
#     path = C:\Users\sergiojesus\Desktop\Document_Clustering\CV_EmanuelOliveira_pt.pdf
#             ^
# SyntaxError: invalid syntax

# %%
from Scripts import pdf2txt

# %%
fp = open(path, 'rb')

# %%
pdf2text(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-184fe9cfd33f> in <module>()
# ----> 1 pdf2text(path)
#
# NameError: name 'pdf2text' is not defined

# %%
import pdfparser

# %%
importlib.reload(pather)
importlib.reload(pdfparser)
# Out:
# <module 'pdfparser' from 'C:\\Users\\sergiojesus\\Desktop\\Document_clustering_concorrente\\pdfparser.py'>

# %%
timer = time.time()
for i in paths[0:5]:
    pdfparser.pdf2string(i)
print(time.time()-timer)
# Out:
# 2.0316150188446045

# %%
import PyPDF2

# %%
timer = time.time()
for i in paths[0:5]:
    pdf = PyPDF2.PdfFileReader(open(i, "rb"))
    for page in pdf.pages:
        text = page.extractText()
print(time.time()-timer)
# Out:
# ...
# 0.5518453121185303
